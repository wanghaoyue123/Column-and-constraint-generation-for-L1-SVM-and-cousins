# %%
import numpy as np
import sys
sys.path.append('./L1SVM_CGCP')
sys.path.append('./real_data')

from Our_methods import use_FOM_CGCP
from Benchmarks import use_SGD, use_SCS, use_PSM, use_Gurobi, use_FOM
from simulate_data_classification import simulate_data_classification
# Out:
# R[write to console]: 载入需要的程辑包：lattice
#
# R[write to console]: 载入需要的程辑包：igraph
#
# R[write to console]:
# 载入程辑包：‘igraph’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# R[write to console]: The following object is masked from ‘package:base’:
#
#     union
#
#
# R[write to console]: 载入需要的程辑包：MASS
#
# R[write to console]: 载入需要的程辑包：Matrix

# %%
## generate data 
## 'trash.txt' is a temperory txt file to save some of the output

N, P = 500, 500
type_Sigma, k0, rho, tau_SNR = 2, 10, 0.1, 1
seed_X = 134
f = open('trash.txt', 'w')
X_train, _, _, y_train, _, _ = simulate_data_classification(type_Sigma, N, P, k0, rho, tau_SNR, seed_X, f, create_test=False)

lam_max = np.max(np.sum( np.abs(X_train), axis=0))
lam = 0.01*lam_max
# Out:
# DATA CREATED for N=500, P=500, k0=10 Rho=0.1 Sigma=2 Seed_X=134

# %%
## Use column generation LP inicialized with first order method (FO-CLG). See the paper for more details.
## The input "tol" is the tolerance parameter for searching reduced cost (the parameter "epsilon" in the paper)

relative_lam = lam/lam_max
obj, time_total, time_CG, beta, beta0 = use_FOM_CGCP(X_train, y_train, lam, relative_lam, tol = 0.01)
# Out:
# ###### SAMPLE NUMBER 1
# ###### DIFFERENCE L2 NORMS 1000000.0
# TEST CV BETWEEN 2 VALUES OF TAU: 10.535653752852738
#
# Number of iterations: 100
# Shape: (110, 110)
# Len support smoothing: 29
# Number violated constraints: 0
# Convergence rate    : 0.087
# Time smoothing: 0.091
# TEST CV BETWEEN 2 VALUES OF TAU: 20.172162451763306
#
# Number of iterations: 50
# Shape: (110, 29)
# Len support smoothing: 26
# Number violated constraints: 0
# Convergence rate    : 0.039
# Time smoothing: 0.043
# TEST CV BETWEEN 2 VALUES OF TAU: 1.9004062504310915
#
# Number of iterations: 50
# Shape: (110, 29)
# Len support smoothing: 25
# Number violated constraints: 0
# Convergence rate    : 0.02
# Time smoothing: 0.044
# TEST CV BETWEEN 2 VALUES OF TAU: 1.0668107795476691
#
# Number of iterations: 50
# Shape: (110, 29)
# Len support smoothing: 24
# Number violated constraints: 0
# Convergence rate    : 0.014
# Time smoothing: 0.045
# TEST CV BETWEEN 2 VALUES OF TAU: 0.7231546448510134
#
# Number of iterations: 50
# Shape: (110, 29)
# Len support smoothing: 23
# Number violated constraints: 1
# Convergence rate    : 0.011
# Time smoothing: 0.024
# TEST CV BETWEEN 2 VALUES OF TAU: 0.5413527780425754
#
# Number of iterations: 50
# Shape: (110, 29)
# Len support smoothing: 23
# Number violated constraints: 10
# Convergence rate    : 0.009
# Time smoothing: 0.024
# TEST CV BETWEEN 2 VALUES OF TAU: 0.4094088502906561
#
# Number of iterations: 50
# Shape: (110, 29)
# Len support smoothing: 23
# Number violated constraints: 21
# Convergence rate    : 0.007
# Time smoothing: 0.025
# TEST CV BETWEEN 2 VALUES OF TAU: 0.3010849748705573
#
# Number of iterations: 50
# Shape: (110, 29)
# Len support smoothing: 23
# Number violated constraints: 22
# Convergence rate    : 0.005
# Time smoothing: 0.026
# TEST CV BETWEEN 2 VALUES OF TAU: 0.2194742064795164
#
# Number of iterations: 50
# Shape: (110, 29)
# Len support smoothing: 23
# Number violated constraints: 24
# Convergence rate    : 0.004
# Time smoothing: 0.027
# TEST CV BETWEEN 2 VALUES OF TAU: 0.15606137686531346
#
# Number of iterations: 50
# Shape: (110, 29)
# Len support smoothing: 23
# Number violated constraints: 26
# Convergence rate    : 0.003
# Time smoothing: 0.023
# TEST CV BETWEEN 2 VALUES OF TAU: 0.10970039096358661
#
# Number of iterations: 50
# Shape: (110, 29)
# Len support smoothing: 23
# Number violated constraints: 26
# Convergence rate    : 0.002
# Time smoothing: 0.025
# TEST CV BETWEEN 2 VALUES OF TAU: 0.07672179520561724
#
# Number of iterations: 50
# Shape: (110, 29)
# Len support smoothing: 23
# Number violated constraints: 26
# Convergence rate    : 0.001
# Time smoothing: 0.024
# TEST CV BETWEEN 2 VALUES OF TAU: 0.05271084756394794
#
# Number of iterations: 18
# Shape: (110, 29)
# Len support smoothing: 23
# Number violated constraints: 26
# Convergence rate    : 0.001
# Time smoothing: 0.009
# TEST CV BETWEEN 2 VALUES OF TAU: 0.022967851613234714
#
# Number of iterations: 1
# Shape: (110, 29)
# Len support smoothing: 23
# Number violated constraints: 26
# Convergence rate    : 0.001
# Time smoothing: 0.001
#
# Number of iterations              : 13
# Total time smoothing for hinge: 0.434
#
#
#
# ###### SAMPLE NUMBER 2
# ###### DIFFERENCE L2 NORMS 16.63306972244131
# TEST CV BETWEEN 2 VALUES OF TAU: 10.535653752852738
#
# Number of iterations: 100
# Shape: (110, 110)
# Len support smoothing: 46
# Number violated constraints: 0
# Convergence rate    : 0.077
# Time smoothing: 0.095
# TEST CV BETWEEN 2 VALUES OF TAU: 18.143076852191935
#
# Number of iterations: 50
# Shape: (110, 46)
# Len support smoothing: 43
# Number violated constraints: 0
# Convergence rate    : 0.018
# Time smoothing: 0.044
# TEST CV BETWEEN 2 VALUES OF TAU: 1.4926272720843794
#
# Number of iterations: 50
# Shape: (110, 46)
# Len support smoothing: 44
# Number violated constraints: 0
# Convergence rate    : 0.015
# Time smoothing: 0.043
# TEST CV BETWEEN 2 VALUES OF TAU: 0.9479813649918157
#
# Number of iterations: 50
# Shape: (110, 46)
# Len support smoothing: 43
# Number violated constraints: 0
# Convergence rate    : 0.011
# Time smoothing: 0.039
# TEST CV BETWEEN 2 VALUES OF TAU: 0.6763334943370498
#
# Number of iterations: 50
# Shape: (110, 46)
# Len support smoothing: 41
# Number violated constraints: 1
# Convergence rate    : 0.007
# Time smoothing: 0.025
# TEST CV BETWEEN 2 VALUES OF TAU: 0.46082358414550195
#
# Number of iterations: 50
# Shape: (110, 46)
# Len support smoothing: 40
# Number violated constraints: 5
# Convergence rate    : 0.005
# Time smoothing: 0.026
# TEST CV BETWEEN 2 VALUES OF TAU: 0.3180690856326928
#
# Number of iterations: 50
# Shape: (110, 46)
# Len support smoothing: 40
# Number violated constraints: 33
# Convergence rate    : 0.004
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.2239002879348423
#
# Number of iterations: 50
# Shape: (110, 46)
# Len support smoothing: 40
# Number violated constraints: 33
# Convergence rate    : 0.003
# Time smoothing: 0.023
# TEST CV BETWEEN 2 VALUES OF TAU: 0.15732686706945856
#
# Number of iterations: 50
# Shape: (110, 46)
# Len support smoothing: 41
# Number violated constraints: 34
# Convergence rate    : 0.002
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.11061430136911078
#
# Number of iterations: 50
# Shape: (110, 46)
# Len support smoothing: 41
# Number violated constraints: 34
# Convergence rate    : 0.001
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.07777127745432896
#
# Number of iterations: 24
# Shape: (110, 46)
# Len support smoothing: 42
# Number violated constraints: 36
# Convergence rate    : 0.001
# Time smoothing: 0.011
# TEST CV BETWEEN 2 VALUES OF TAU: 0.04651610761216347
#
# Number of iterations: 18
# Shape: (110, 46)
# Len support smoothing: 43
# Number violated constraints: 37
# Convergence rate    : 0.001
# Time smoothing: 0.008
# TEST CV BETWEEN 2 VALUES OF TAU: 0.0325428478782031
#
# Number of iterations: 13
# Shape: (110, 46)
# Len support smoothing: 43
# Number violated constraints: 37
# Convergence rate    : 0.001
# Time smoothing: 0.007
# TEST CV BETWEEN 2 VALUES OF TAU: 0.020045188608861588
#
# Number of iterations: 11
# Shape: (110, 46)
# Len support smoothing: 42
# Number violated constraints: 37
# Convergence rate    : 0.001
# Time smoothing: 0.006
# TEST CV BETWEEN 2 VALUES OF TAU: 0.012875633841988797
#
# Number of iterations: 1
# Shape: (110, 46)
# Len support smoothing: 41
# Number violated constraints: 37
# Convergence rate    : 0.001
# Time smoothing: 0.001
#
# Number of iterations              : 14
# Total time smoothing for hinge: 0.397
#
#
#
# ###### SAMPLE NUMBER 3
# ###### DIFFERENCE L2 NORMS 4.75341694164326
# TEST CV BETWEEN 2 VALUES OF TAU: 10.535653752852738
#
# Number of iterations: 100
# Shape: (110, 110)
# Len support smoothing: 30
# Number violated constraints: 0
# Convergence rate    : 0.063
# Time smoothing: 0.087
# TEST CV BETWEEN 2 VALUES OF TAU: 20.995818148647782
#
# Number of iterations: 50
# Shape: (110, 30)
# Len support smoothing: 27
# Number violated constraints: 0
# Convergence rate    : 0.035
# Time smoothing: 0.042
# TEST CV BETWEEN 2 VALUES OF TAU: 1.9031583426549388
#
# Number of iterations: 50
# Shape: (110, 30)
# Len support smoothing: 28
# Number violated constraints: 0
# Convergence rate    : 0.022
# Time smoothing: 0.042
# TEST CV BETWEEN 2 VALUES OF TAU: 1.1700488243090041
#
# Number of iterations: 50
# Shape: (110, 30)
# Len support smoothing: 28
# Number violated constraints: 0
# Convergence rate    : 0.016
# Time smoothing: 0.041
# TEST CV BETWEEN 2 VALUES OF TAU: 0.8086774496795901
#
# Number of iterations: 50
# Shape: (110, 30)
# Len support smoothing: 28
# Number violated constraints: 1
# Convergence rate    : 0.012
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.5723959210393124
#
# Number of iterations: 50
# Shape: (110, 30)
# Len support smoothing: 28
# Number violated constraints: 10
# Convergence rate    : 0.009
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.40028736463717157
#
# Number of iterations: 50
# Shape: (110, 30)
# Len support smoothing: 28
# Number violated constraints: 24
# Convergence rate    : 0.007
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.2740413712690482
#
# Number of iterations: 50
# Shape: (110, 30)
# Len support smoothing: 28
# Number violated constraints: 25
# Convergence rate    : 0.005
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.19013990170809505
#
# Number of iterations: 50
# Shape: (110, 30)
# Len support smoothing: 28
# Number violated constraints: 27
# Convergence rate    : 0.003
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.13305506606899858
#
# Number of iterations: 50
# Shape: (110, 30)
# Len support smoothing: 28
# Number violated constraints: 27
# Convergence rate    : 0.002
# Time smoothing: 0.023
# TEST CV BETWEEN 2 VALUES OF TAU: 0.09319392775327101
#
# Number of iterations: 50
# Shape: (110, 30)
# Len support smoothing: 29
# Number violated constraints: 27
# Convergence rate    : 0.002
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.06533837499605291
#
# Number of iterations: 21
# Shape: (110, 30)
# Len support smoothing: 29
# Number violated constraints: 27
# Convergence rate    : 0.001
# Time smoothing: 0.009
# TEST CV BETWEEN 2 VALUES OF TAU: 0.03393340338899133
#
# Number of iterations: 16
# Shape: (110, 30)
# Len support smoothing: 29
# Number violated constraints: 27
# Convergence rate    : 0.001
# Time smoothing: 0.008
# TEST CV BETWEEN 2 VALUES OF TAU: 0.02042965851309483
#
# Number of iterations: 1
# Shape: (110, 30)
# Len support smoothing: 28
# Number violated constraints: 27
# Convergence rate    : 0.001
# Time smoothing: 0.001
#
# Number of iterations              : 13
# Total time smoothing for hinge: 0.387
#
#
#
# ###### SAMPLE NUMBER 4
# ###### DIFFERENCE L2 NORMS 4.0666758129603995
# TEST CV BETWEEN 2 VALUES OF TAU: 10.535653752852738
#
# Number of iterations: 100
# Shape: (110, 110)
# Len support smoothing: 32
# Number violated constraints: 0
# Convergence rate    : 0.12
# Time smoothing: 0.086
# TEST CV BETWEEN 2 VALUES OF TAU: 21.50216731199626
#
# Number of iterations: 50
# Shape: (110, 32)
# Len support smoothing: 29
# Number violated constraints: 0
# Convergence rate    : 0.038
# Time smoothing: 0.039
# TEST CV BETWEEN 2 VALUES OF TAU: 1.8502548068936815
#
# Number of iterations: 50
# Shape: (110, 32)
# Len support smoothing: 28
# Number violated constraints: 1
# Convergence rate    : 0.021
# Time smoothing: 0.038
# TEST CV BETWEEN 2 VALUES OF TAU: 1.108523035919205
#
# Number of iterations: 50
# Shape: (110, 32)
# Len support smoothing: 28
# Number violated constraints: 1
# Convergence rate    : 0.016
# Time smoothing: 0.039
# TEST CV BETWEEN 2 VALUES OF TAU: 0.8278716886637149
#
# Number of iterations: 50
# Shape: (110, 32)
# Len support smoothing: 29
# Number violated constraints: 1
# Convergence rate    : 0.013
# Time smoothing: 0.024
# TEST CV BETWEEN 2 VALUES OF TAU: 0.5851715037720664
#
# Number of iterations: 50
# Shape: (110, 32)
# Len support smoothing: 29
# Number violated constraints: 11
# Convergence rate    : 0.009
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.41689044291121075
#
# Number of iterations: 50
# Shape: (110, 32)
# Len support smoothing: 29
# Number violated constraints: 23
# Convergence rate    : 0.007
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.29610193425452075
#
# Number of iterations: 50
# Shape: (110, 32)
# Len support smoothing: 30
# Number violated constraints: 24
# Convergence rate    : 0.005
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.21169466378962384
#
# Number of iterations: 50
# Shape: (110, 32)
# Len support smoothing: 30
# Number violated constraints: 24
# Convergence rate    : 0.004
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.15578431688799568
#
# Number of iterations: 50
# Shape: (110, 32)
# Len support smoothing: 26
# Number violated constraints: 24
# Convergence rate    : 0.003
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.10745372767303205
#
# Number of iterations: 50
# Shape: (110, 32)
# Len support smoothing: 26
# Number violated constraints: 24
# Convergence rate    : 0.002
# Time smoothing: 0.022
# TEST CV BETWEEN 2 VALUES OF TAU: 0.07479058639260072
#
# Number of iterations: 50
# Shape: (110, 32)
# Len support smoothing: 26
# Number violated constraints: 26
# Convergence rate    : 0.001
# Time smoothing: 0.023
# TEST CV BETWEEN 2 VALUES OF TAU: 0.05245437664610593
#
# Number of iterations: 15
# Shape: (110, 32)
# Len support smoothing: 27
# Number violated constraints: 26
# Convergence rate    : 0.001
# Time smoothing: 0.007
# TEST CV BETWEEN 2 VALUES OF TAU: 0.019622666140863065
#
# Number of iterations: 1
# Shape: (110, 32)
# Len support smoothing: 26
# Number violated constraints: 26
# Convergence rate    : 0.001
# Time smoothing: 0.001
#
# Number of iterations              : 13
# Total time smoothing for hinge: 0.391
# Len support primal: 84
# Len dual smoothing: 119
# Total time: 1.633
# <class 'numpy.ndarray'> False OK Gurobi model
# Size of model: [119, 200]
# Using license file /home/software/gurobi/gurobi.lic
# Set parameter TokenServer to value engaging-license-001
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter TimeLimit to 3600.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# ------------------------------------------------------
# Round 1
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (linux64)
# Optimize a model with 119 rows, 520 columns and 47838 nonzeros
# Model fingerprint: 0x75b90b10
# Coefficient statistics:
#   Matrix range     [2e-06, 1e+00]
#   Objective range  [2e-01, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.02s
# Presolved: 119 rows, 520 columns, 47838 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 1
#  AA' NZ     : 7.021e+03
#  Factor NZ  : 7.140e+03
#  Factor Ops : 5.688e+05 (less than 1 second per iteration)
#  Threads    : 26
#
# Barrier performed 0 iterations in 0.10 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 178 iterations and 0.11 seconds
# Optimal objective  1.525062466e+01
# Time optimizing = 0.49522948265075684
# Number of columns added: 49
# Max violated column    : -0.248
# Time adding columns = 0.5466165542602539
# Number of constraints added: 10
# Max violated constraint    : 0.259
# ------------------------------------------------------
# Round 2
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (linux64)
# Optimize a model with 129 rows, 628 columns and 64500 nonzeros
# Coefficient statistics:
#   Matrix range     [2e-06, 1e+00]
#   Objective range  [2e-01, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.0219603e+31   5.027019e+32   2.021960e+01      0s
#      226    1.4388138e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 226 iterations and 0.03 seconds
# Optimal objective  1.438813849e+01
# Time optimizing = 0.638474702835083
# Number of columns added: 9
# Max violated column    : -0.132
# Time adding columns = 0.6531050205230713
# Number of constraints added: 5
# Max violated constraint    : 0.32
# ------------------------------------------------------
# Round 3
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (linux64)
# Optimize a model with 134 rows, 651 columns and 69412 nonzeros
# Coefficient statistics:
#   Matrix range     [2e-06, 1e+00]
#   Objective range  [2e-01, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.2124685e+30   2.418531e+32   3.212469e+00      0s
#      124    1.4305799e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 124 iterations and 0.02 seconds
# Optimal objective  1.430579861e+01
# Time optimizing = 0.7106826305389404
# Number of columns added: 2
# Max violated column    : -0.02
# Time adding columns = 0.7223391532897949
# Number of constraints added: 3
# Max violated constraint    : 0.153
# ------------------------------------------------------
# Round 4
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (linux64)
# Optimize a model with 137 rows, 658 columns and 71514 nonzeros
# Coefficient statistics:
#   Matrix range     [2e-06, 1e+00]
#   Objective range  [2e-01, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.5561451e+29   1.221980e+32   2.556145e-01      0s
#       47    1.4350287e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 47 iterations and 0.02 seconds
# Optimal objective  1.435028693e+01
# Time optimizing = 0.7609364986419678
# Number of columns added: 1
# Max violated column    : -0.027
# Time adding columns = 0.7705349922180176
# ------------------------------------------------------
# Round 5
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (linux64)
# Optimize a model with 137 rows, 660 columns and 71788 nonzeros
# Coefficient statistics:
#   Matrix range     [2e-06, 1e+00]
#   Objective range  [2e-01, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.1522483e+29   9.166334e+31   2.152248e-01      0s
#       26    1.4346981e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 26 iterations and 0.01 seconds
# Optimal objective  1.434698083e+01
# Time optimizing = 0.7844705581665039
#
# TIME CG-CP = 0.7961623668670654
#
# Obj value   = 14.346980828663192
# Len support = 62
# b0   = 0.056994971765855724
#
# Number violated constraints =  28
# Len support dual = 63

# %%
## Use SCS

obj, runtime, beta, beta0 = use_SCS(X_train, y_train, lam)
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.1 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 254001
# eps = 1.00e-04, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 1502, constraints m = 2001
# Cones:	linear vars: 2001
# Setup time: 2.06e-01s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 2.37e+20  4.64e+20  1.00e+00 -6.19e+22  9.37e+22  4.98e+22  5.13e-03
#    100| 4.84e-03  3.44e-02  5.95e-03  1.44e+01  1.46e+01  3.52e-14  2.26e-01
#    200| 2.87e-03  5.38e-03  1.34e-02  1.47e+01  1.51e+01  3.17e-15  4.20e-01
#    300| 1.83e-03  8.16e-03  1.61e-04  1.43e+01  1.43e+01  2.90e-15  6.15e-01
#    400| 1.06e-03  3.09e-03  1.96e-03  1.43e+01  1.43e+01  1.14e-15  8.06e-01
#    500| 6.26e-04  1.98e-03  7.84e-04  1.43e+01  1.43e+01  1.42e-14  9.98e-01
#    600| 6.41e-04  8.05e-04  9.82e-04  1.44e+01  1.43e+01  8.51e-15  1.19e+00
#    700| 2.78e-04  1.46e-03  1.95e-04  1.44e+01  1.44e+01  1.65e-14  1.39e+00
#    800| 3.12e-04  1.55e-03  3.13e-04  1.43e+01  1.44e+01  3.12e-14  1.58e+00
#    900| 1.40e-04  5.89e-04  5.15e-04  1.43e+01  1.43e+01  1.13e-14  1.78e+00
#   1000| 1.40e-04  2.59e-04  1.10e-04  1.43e+01  1.43e+01  3.24e-14  1.97e+00
#   1100| 1.09e-04  6.46e-04  1.38e-04  1.43e+01  1.43e+01  1.66e-14  2.17e+00
#   1200| 1.69e-04  2.87e-04  2.17e-04  1.44e+01  1.44e+01  1.40e-14  2.36e+00
#   1300| 2.16e-04  1.93e-03  5.57e-06  1.44e+01  1.44e+01  2.79e-14  2.56e+00
#   1400| 1.47e-04  7.37e-04  1.02e-04  1.43e+01  1.44e+01  1.84e-14  2.75e+00
#   1500| 7.14e-05  7.49e-04  4.37e-06  1.43e+01  1.43e+01  4.83e-15  2.94e+00
#   1600| 4.59e-05  4.60e-04  2.18e-04  1.43e+01  1.44e+01  8.94e-15  3.13e+00
#   1700| 1.20e-04  8.45e-04  3.00e-05  1.43e+01  1.43e+01  1.93e-14  3.32e+00
#   1800| 6.46e-05  3.55e-04  1.11e-04  1.44e+01  1.44e+01  1.06e-14  3.50e+00
#   1900| 8.19e-05  1.10e-03  2.80e-04  1.43e+01  1.43e+01  2.99e-14  3.68e+00
#   2000| 5.94e-05  3.74e-04  1.42e-04  1.43e+01  1.44e+01  7.79e-15  3.87e+00
#   2100| 7.64e-05  2.91e-04  1.57e-04  1.44e+01  1.44e+01  2.01e-14  4.05e+00
#   2200| 1.40e-04  3.50e-04  1.41e-04  1.43e+01  1.43e+01  8.30e-15  4.23e+00
#   2300| 8.40e-05  7.81e-04  1.59e-04  1.43e+01  1.43e+01  5.16e-15  4.42e+00
#   2400| 9.73e-05  7.52e-04  6.20e-06  1.44e+01  1.44e+01  2.33e-14  4.59e+00
#   2500| 5.27e-05  3.64e-04  4.74e-05  1.43e+01  1.43e+01  2.00e-14  4.78e+00
#   2600| 4.28e-05  4.83e-04  8.96e-05  1.43e+01  1.43e+01  6.93e-15  4.95e+00
#   2700| 2.82e-05  1.79e-04  4.05e-05  1.43e+01  1.43e+01  2.72e-16  5.14e+00
#   2800| 7.68e-05  6.82e-04  1.81e-04  1.43e+01  1.44e+01  8.37e-15  5.32e+00
#   2880| 3.59e-05  7.47e-05  6.02e-05  1.43e+01  1.43e+01  4.45e-15  5.47e+00
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 5.47e+00s
# 	Lin-sys: nnz in L factor: 508004, avg solve time: 1.35e-03s
# 	Cones: avg projection time: 1.78e-06s
# 	Acceleration: avg step time: 4.42e-04s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.4010e-16, dist(y, K*) = 0.0000e+00, s'y/|s||y| = 7.3346e-19
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 3.5924e-05
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 7.4747e-05
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 6.0151e-05
# ----------------------------------------------------------------------------
# c'x = 14.3478, -b'y = 14.3496
# ============================================================================

# %%
## Use Gurobi LP solver 

obj, runtime, beta, beta0 = use_Gurobi(X_train, y_train, lam)
# Out:
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (linux64)
# Optimize a model with 2001 rows, 1502 columns and 254001 nonzeros
# Model fingerprint: 0x70277eca
# Coefficient statistics:
#   Matrix range     [8e-07, 1e+00]
#   Objective range  [2e-01, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 1001 rows and 1 columns
# Presolve time: 0.18s
# Presolved: 1000 rows, 1501 columns, 252000 nonzeros
#
#
# Barrier performed 0 iterations in 0.25 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 861 iterations and 0.25 seconds
# Optimal objective  1.434682969e+01

# %%
## Use gradient descent with Nesterov's smoothing 

obj, runtime, beta, beta0 = use_FOM(X_train, y_train, lam, tau = 0.02, max_iter = 1000)
# Out:
# TEST CV BEFORE TAU: 22.38302928559939
#
# Number of iterations: 1000
# Shape: (500, 500)
# Len support smoothing: 69
# Number violated constraints: 70
# Convergence rate    : 0.002
# Time smoothing: 3.828
#
# Number of iterations              : 1
# Total time smoothing for hinge: 3.831

# %%
## Use SGD with 10000 epochs

max_iter = 10000
obj, runtime, beta, beta0 = use_SGD(X_train, y_train, lam, max_iter)
