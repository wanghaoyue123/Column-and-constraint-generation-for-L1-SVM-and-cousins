# %%
import numpy as np
import sys
sys.path.append('./L1SVM_CP')


from Our_methods import use_FOM_CP
from Benchmarks import use_SGD, use_SCS, use_Gurobi, use_FOM
from simulate_data_classification import simulate_data_classification
# Out:
# R[write to console]: 载入需要的程辑包：lattice
#
# R[write to console]: 载入需要的程辑包：igraph
#
# R[write to console]:
# 载入程辑包：‘igraph’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# R[write to console]: The following object is masked from ‘package:base’:
#
#     union
#
#
# R[write to console]: 载入需要的程辑包：MASS
#
# R[write to console]: 载入需要的程辑包：Matrix

# %%
## generate data 
## 'trash.txt' is a temperory txt file to save some of the output

N, P = 1000, 100
type_Sigma, k0, rho, tau_SNR = 2, 10, 0.1, 1
seed_X = 155
f = open('trash.txt', 'w')
X_train, _, _, y_train, _, _ = simulate_data_classification(type_Sigma, N, P, k0, rho, tau_SNR, seed_X, f, create_test=False)

lam_max = np.max(np.sum( np.abs(X_train), axis=0))
lam = 0.01*lam_max
# Out:
# DATA CREATED for N=1000, P=100, k0=10 Rho=0.1 Sigma=2 Seed_X=155

# %%
## Use column generation LP inicialized with first order method (FO-CLG). See the paper for more details.
## The input "tol" is the tolerance parameter for searching reduced cost (the parameter "epsilon" in the paper)

relative_lam = lam/lam_max
obj, time_total, time_CG, beta, beta0 = use_FOM_CP(X_train, y_train, lam, relative_lam, tol = 0.01)
# Out:
# ###### SAMPLE NUMBER 1
# ###### DIFFERENCE VARIANCE 1000000.0
# TEST CV BEFORE TAU
# 10.04987562112089
#
# Number of iterations: 20
# Shape: (250, 100)
# Len support smoothing: 95
# Number violated constraints: 13
# Convergence rate    : 0.522
# Time smoothing: 0.035
# TEST CV BEFORE TAU
# 27.285912591197505
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 35
# Number violated constraints: 5
# Convergence rate    : 1.229
# Time smoothing: 0.007
# TEST CV BEFORE TAU
# 17.83755194009669
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 27
# Number violated constraints: 5
# Convergence rate    : 0.424
# Time smoothing: 0.006
# TEST CV BEFORE TAU
# 5.78727302764243
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 26
# Number violated constraints: 5
# Convergence rate    : 0.215
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 2.6346334929327364
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 26
# Number violated constraints: 5
# Convergence rate    : 0.149
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 1.7715250568756054
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 27
# Number violated constraints: 5
# Convergence rate    : 0.105
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 1.2418744758544253
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 26
# Number violated constraints: 5
# Convergence rate    : 0.061
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 0.7821599974166351
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 25
# Number violated constraints: 5
# Convergence rate    : 0.034
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 0.4514526172338947
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 24
# Number violated constraints: 5
# Convergence rate    : 0.023
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 0.282312633877164
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 24
# Number violated constraints: 5
# Convergence rate    : 0.016
# Time smoothing: 0.006
# TEST CV BEFORE TAU
# 0.1965013528153936
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 23
# Number violated constraints: 5
# Convergence rate    : 0.011
# Time smoothing: 0.006
#
# Number of iterations              : 10
# Total time smoothing for hinge: 0.098
#
#
#
# ###### SAMPLE NUMBER 2
# ###### DIFFERENCE VARIANCE 21.83958713330177
# TEST CV BEFORE TAU
# 10.04987562112089
#
# Number of iterations: 20
# Shape: (250, 100)
# Len support smoothing: 93
# Number violated constraints: 13
# Convergence rate    : 0.433
# Time smoothing: 0.033
# TEST CV BEFORE TAU
# 27.086610192124667
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 36
# Number violated constraints: 6
# Convergence rate    : 1.02
# Time smoothing: 0.006
# TEST CV BEFORE TAU
# 14.277141783828037
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 28
# Number violated constraints: 6
# Convergence rate    : 0.407
# Time smoothing: 0.006
# TEST CV BEFORE TAU
# 5.41476524089973
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 28
# Number violated constraints: 6
# Convergence rate    : 0.278
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 3.2928117450766985
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 27
# Number violated constraints: 6
# Convergence rate    : 0.134
# Time smoothing: 0.006
# TEST CV BEFORE TAU
# 2.0218506041263122
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 26
# Number violated constraints: 6
# Convergence rate    : 0.081
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 0.9830817271273758
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 26
# Number violated constraints: 6
# Convergence rate    : 0.057
# Time smoothing: 0.006
# TEST CV BEFORE TAU
# 0.677152110300217
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 26
# Number violated constraints: 6
# Convergence rate    : 0.04
# Time smoothing: 0.006
# TEST CV BEFORE TAU
# 0.473948602115445
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 26
# Number violated constraints: 6
# Convergence rate    : 0.028
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 0.33172843684347314
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 26
# Number violated constraints: 9
# Convergence rate    : 0.019
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 0.23220672007587256
#
# Number of iterations: 20
# Shape: (13, 100)
# Len support smoothing: 25
# Number violated constraints: 13
# Convergence rate    : 0.013
# Time smoothing: 0.006
#
# Number of iterations              : 10
# Total time smoothing for hinge: 0.096
#
#
#
# ###### SAMPLE NUMBER 3
# ###### DIFFERENCE VARIANCE 14.988197925012305
# TEST CV BEFORE TAU
# 10.04987562112089
#
# Number of iterations: 20
# Shape: (250, 100)
# Len support smoothing: 91
# Number violated constraints: 9
# Convergence rate    : 0.419
# Time smoothing: 0.035
# TEST CV BEFORE TAU
# 27.052757369819687
#
# Number of iterations: 20
# Shape: (9, 100)
# Len support smoothing: 36
# Number violated constraints: 4
# Convergence rate    : 1.123
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 14.785449134684566
#
# Number of iterations: 20
# Shape: (9, 100)
# Len support smoothing: 30
# Number violated constraints: 4
# Convergence rate    : 0.473
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 7.471492110061419
#
# Number of iterations: 20
# Shape: (9, 100)
# Len support smoothing: 24
# Number violated constraints: 4
# Convergence rate    : 0.273
# Time smoothing: 0.006
# TEST CV BEFORE TAU
# 3.5146906188419096
#
# Number of iterations: 20
# Shape: (9, 100)
# Len support smoothing: 21
# Number violated constraints: 4
# Convergence rate    : 0.151
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 1.8098717367681956
#
# Number of iterations: 20
# Shape: (9, 100)
# Len support smoothing: 20
# Number violated constraints: 4
# Convergence rate    : 0.099
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 1.1849501682941332
#
# Number of iterations: 20
# Shape: (9, 100)
# Len support smoothing: 20
# Number violated constraints: 4
# Convergence rate    : 0.069
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 0.8235808599641987
#
# Number of iterations: 20
# Shape: (9, 100)
# Len support smoothing: 20
# Number violated constraints: 4
# Convergence rate    : 0.049
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 0.5763385924433588
#
# Number of iterations: 20
# Shape: (9, 100)
# Len support smoothing: 18
# Number violated constraints: 4
# Convergence rate    : 0.029
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 0.35635737593956535
#
# Number of iterations: 20
# Shape: (9, 100)
# Len support smoothing: 18
# Number violated constraints: 4
# Convergence rate    : 0.02
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 0.24429484726619366
#
# Number of iterations: 20
# Shape: (9, 100)
# Len support smoothing: 17
# Number violated constraints: 4
# Convergence rate    : 0.013
# Time smoothing: 0.005
#
# Number of iterations              : 10
# Total time smoothing for hinge: 0.089
#
#
#
# ###### SAMPLE NUMBER 4
# ###### DIFFERENCE VARIANCE 6.828445551892268
# TEST CV BEFORE TAU
# 10.04987562112089
#
# Number of iterations: 20
# Shape: (250, 100)
# Len support smoothing: 91
# Number violated constraints: 7
# Convergence rate    : 0.398
# Time smoothing: 0.033
# TEST CV BEFORE TAU
# 27.407411959034857
#
# Number of iterations: 20
# Shape: (7, 100)
# Len support smoothing: 28
# Number violated constraints: 2
# Convergence rate    : 1.536
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 22.659998158245607
#
# Number of iterations: 20
# Shape: (7, 100)
# Len support smoothing: 18
# Number violated constraints: 2
# Convergence rate    : 0.519
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 6.7074683886639885
#
# Number of iterations: 20
# Shape: (7, 100)
# Len support smoothing: 13
# Number violated constraints: 2
# Convergence rate    : 0.232
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 2.880203839151829
#
# Number of iterations: 20
# Shape: (7, 100)
# Len support smoothing: 12
# Number violated constraints: 2
# Convergence rate    : 0.162
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 1.9201268447330513
#
# Number of iterations: 20
# Shape: (7, 100)
# Len support smoothing: 12
# Number violated constraints: 2
# Convergence rate    : 0.113
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 1.3448787756149683
#
# Number of iterations: 20
# Shape: (7, 100)
# Len support smoothing: 12
# Number violated constraints: 2
# Convergence rate    : 0.079
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 0.9413415032430249
#
# Number of iterations: 20
# Shape: (7, 100)
# Len support smoothing: 12
# Number violated constraints: 2
# Convergence rate    : 0.056
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 0.6589446160716507
#
# Number of iterations: 20
# Shape: (7, 100)
# Len support smoothing: 12
# Number violated constraints: 2
# Convergence rate    : 0.039
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 0.46126080138390707
#
# Number of iterations: 20
# Shape: (7, 100)
# Len support smoothing: 12
# Number violated constraints: 2
# Convergence rate    : 0.027
# Time smoothing: 0.005
# TEST CV BEFORE TAU
# 0.32288259472864417
#
# Number of iterations: 20
# Shape: (7, 100)
# Len support smoothing: 12
# Number violated constraints: 2
# Convergence rate    : 0.019
# Time smoothing: 0.005
#
# Number of iterations              : 10
# Total time smoothing for hinge: 0.084
#
#
#
# FINISHED
# Len dual smoothing: 946
# Total time: 0.382
# Size of model: [946, 100]
# Using license file /home/software/gurobi/gurobi.lic
# Set parameter TokenServer to value engaging-license-001
# Time optimizing = 1.4124493598937988
# Number of rounds: 1
#
# TIME CP = 1.4148435592651367
#
# Obj value   = 43.337197340170626
# Len support = 46
#
# Number violated constraints =  55
# Len support dual = 68
# Solution dual = 43.337197340170626
# Solution primal test = 43.337197340170654

# %%
## Use SCS

obj, runtime, beta, beta0 = use_SCS(X_train, y_train, lam)
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.1 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 103501
# eps = 1.00e-04, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 1202, constraints m = 2201
# Cones:	linear vars: 2201
# Setup time: 3.38e-02s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 2.58e+20  5.40e+20  1.00e+00 -1.22e+23  2.38e+23  8.78e+22  4.61e-03
#    100| 6.09e-03  6.95e-02  9.19e-03  4.34e+01  4.26e+01  4.11e-14  1.24e-01
#    200| 2.37e-03  2.67e-02  4.61e-03  4.38e+01  4.42e+01  1.97e-14  2.25e-01
#    300| 2.33e-03  3.30e-02  2.42e-03  4.30e+01  4.32e+01  7.99e-15  3.28e-01
#    400| 1.27e-03  2.69e-03  1.34e-03  4.34e+01  4.33e+01  1.75e-15  4.31e-01
#    500| 1.44e-03  5.64e-03  7.89e-04  4.33e+01  4.33e+01  3.32e-14  5.33e-01
#    600| 1.08e-03  1.09e-02  2.56e-03  4.33e+01  4.31e+01  4.98e-14  6.36e-01
#    700| 7.81e-04  2.35e-03  1.23e-03  4.35e+01  4.36e+01  8.37e-14  7.37e-01
#    800| 3.41e-04  4.06e-04  1.26e-04  4.33e+01  4.33e+01  1.25e-14  8.44e-01
#    900| 2.65e-04  2.19e-03  4.34e-04  4.33e+01  4.33e+01  2.98e-14  9.48e-01
#   1000| 8.22e-04  2.39e-03  1.16e-03  4.33e+01  4.32e+01  7.16e-14  1.06e+00
#   1100| 2.66e-04  4.56e-03  5.20e-04  4.33e+01  4.33e+01  2.16e-14  1.16e+00
#   1200| 2.67e-04  3.10e-03  1.56e-04  4.34e+01  4.33e+01  3.72e-14  1.26e+00
#   1300| 2.99e-04  3.84e-03  5.86e-04  4.33e+01  4.32e+01  9.25e-14  1.37e+00
#   1400| 2.46e-04  3.50e-03  3.29e-04  4.34e+01  4.34e+01  1.28e-15  1.48e+00
#   1500| 3.06e-04  9.75e-04  7.17e-05  4.33e+01  4.33e+01  4.42e-14  1.58e+00
#   1600| 2.05e-04  2.83e-03  2.78e-04  4.34e+01  4.34e+01  1.00e-13  1.69e+00
#   1700| 2.25e-04  4.12e-04  6.61e-05  4.34e+01  4.33e+01  2.78e-14  1.79e+00
#   1800| 8.54e-05  1.30e-03  3.95e-04  4.33e+01  4.33e+01  2.02e-14  1.90e+00
#   1900| 1.81e-04  5.96e-04  6.45e-05  4.33e+01  4.33e+01  5.24e-14  2.00e+00
#   2000| 1.31e-04  1.02e-03  1.61e-04  4.34e+01  4.34e+01  2.85e-14  2.11e+00
#   2100| 8.26e-05  4.36e-04  8.29e-05  4.33e+01  4.33e+01  4.25e-14  2.22e+00
#   2200| 1.08e-04  9.02e-04  7.48e-06  4.33e+01  4.33e+01  2.72e-14  2.33e+00
#   2300| 1.36e-04  1.04e-03  1.19e-04  4.33e+01  4.33e+01  3.60e-14  2.43e+00
#   2400| 1.06e-04  5.41e-04  2.33e-05  4.34e+01  4.34e+01  4.89e-14  2.54e+00
#   2500| 6.62e-05  1.62e-04  1.97e-04  4.33e+01  4.33e+01  1.48e-14  2.64e+00
#   2600| 8.86e-05  7.90e-04  6.40e-05  4.33e+01  4.34e+01  1.68e-14  2.74e+00
#   2700| 1.64e-04  9.54e-04  1.65e-04  4.34e+01  4.33e+01  6.92e-14  2.84e+00
#   2800| 8.83e-05  3.08e-04  2.79e-04  4.33e+01  4.33e+01  4.07e-14  2.95e+00
#   2900| 9.87e-05  1.52e-04  2.36e-04  4.33e+01  4.33e+01  5.41e-14  3.06e+00
#   3000| 2.80e-04  1.10e-03  3.01e-04  4.33e+01  4.33e+01  3.21e-14  3.16e+00
#   3100| 1.37e-04  1.90e-03  2.49e-05  4.33e+01  4.33e+01  1.03e-13  3.27e+00
#   3200| 2.25e-04  3.52e-03  9.51e-04  4.33e+01  4.32e+01  4.64e-14  3.37e+00
#   3300| 1.23e-04  8.48e-04  7.04e-05  4.33e+01  4.33e+01  1.38e-14  3.47e+00
#   3400| 2.15e-04  2.27e-03  1.84e-04  4.34e+01  4.34e+01  6.24e-14  3.58e+00
#   3500| 1.67e-04  1.49e-03  5.40e-04  4.33e+01  4.33e+01  5.01e-14  3.68e+00
#   3600| 1.55e-04  1.22e-03  2.45e-04  4.33e+01  4.34e+01  4.98e-15  3.79e+00
#   3700| 1.79e-04  2.50e-04  3.51e-04  4.33e+01  4.33e+01  2.35e-14  3.89e+00
#   3800| 1.64e-04  6.40e-04  6.74e-05  4.33e+01  4.33e+01  6.79e-14  3.99e+00
#   3900| 9.68e-05  4.19e-04  3.51e-04  4.33e+01  4.33e+01  2.12e-14  4.10e+00
#   4000| 1.49e-04  6.14e-04  2.08e-04  4.33e+01  4.33e+01  6.61e-14  4.20e+00
#   4100| 2.26e-04  2.37e-03  3.79e-06  4.33e+01  4.33e+01  2.23e-14  4.30e+00
#   4200| 7.17e-05  1.91e-04  2.40e-04  4.33e+01  4.33e+01  7.06e-14  4.41e+00
#   4240| 5.07e-05  8.02e-05  2.32e-05  4.33e+01  4.33e+01  1.48e-14  4.45e+00
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 4.45e+00s
# 	Lin-sys: nnz in L factor: 213350, avg solve time: 7.28e-04s
# 	Cones: avg projection time: 2.41e-06s
# 	Acceleration: avg step time: 2.41e-04s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.3100e-16, dist(y, K*) = 0.0000e+00, s'y/|s||y| = 4.2836e-19
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 5.0707e-05
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 8.0158e-05
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 2.3208e-05
# ----------------------------------------------------------------------------
# c'x = 43.3264, -b'y = 43.3243
# ============================================================================

# %%
## Use Gurobi LP solver 

obj, runtime, beta, beta0 = use_Gurobi(X_train, y_train, lam)
# Out:
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter QCPDual to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (linux64)
# Optimize a model with 2201 rows, 1202 columns and 103501 nonzeros
# Model fingerprint: 0x207e74e6
# Coefficient statistics:
#   Matrix range     [4e-07, 1e+00]
#   Objective range  [3e-01, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 1101 rows and 1 columns
# Presolve time: 0.06s
# Presolved: 1100 rows, 1201 columns, 102200 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  Dense cols : 101
#  Free vars  : 101
#  AA' NZ     : 1.011e+05
#  Factor NZ  : 1.188e+05 (roughly 2 MBytes of memory)
#  Factor Ops : 1.326e+07 (less than 1 second per iteration)
#  Threads    : 26
#
# Barrier performed 0 iterations in 0.20 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 330 iterations and 0.21 seconds
# Optimal objective  4.333719734e+01

# %%
## Use gradient descent with Nesterov's smoothing 

obj, runtime, beta, beta0 = use_FOM(X_train, y_train, lam, tau = 0.02, max_iter = 1000)
# Out:
# TEST CV BEFORE TAU: 10.04987562112089
#
# Number of iterations: 1397
# Shape: (1000, 100)
# Len support smoothing: 49
# Number violated constraints: 76
# Convergence rate    : 0.001
# Time smoothing: 8.328
#
# Number of iterations              : 1
# Total time smoothing for hinge: 8.33

# %%
## Use SGD with 10000 epochs

max_iter = 10000
obj, runtime, beta, beta0 = use_SGD(X_train, y_train, lam, max_iter)
